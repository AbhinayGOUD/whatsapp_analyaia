# %%
import pandas as pd

# %%
chat=pd.read_excel('chat1.xlsx')
#pd.set_option('display.max_columns',None)

# %%
chat.head()
# Out:
#            Date         Time              Name  \
# 0     [21/03/20   7:35:35 AM      ABHINAY GOUD
# 1  ƒ??[21/03/20   2:47:36 PM   Tss Shivasenkar
# 2  ƒ??[21/03/20   3:38:27 PM   Tss Shivasenkar
# 3     [21/03/20   6:27:09 PM      ABHINAY GOUD
# 4     [21/03/20   6:27:25 PM      ABHINAY GOUD
#
#                                              Message Unnamed: 4 Unnamed: 5  \
# 0                  Key window Dagara petta\t\t\t\t\t        NaN        NaN
# 1     ANNAMACHARYA.rar Ÿ??document omitted\t\t\t\t\t        NaN        NaN
# 2   pick and place robot.rar Ÿ??document omitted\...        NaN        NaN
# 3         Kshtriya complete chesi pettandi\t\t\t\t\t        NaN        NaN
# 4           After ugadi vastharu pillaging\t\t\t\t\t        NaN        NaN
#
#   Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0        NaN         NaN        NaN        NaN         NaN
# 1        NaN         NaN        NaN        NaN         NaN
# ...

# %%
chat.drop(['Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10'],axis=1,inplace=True)

# %%
chat.head()
# Out:
#            Date         Time              Name  \
# 0     [21/03/20   7:35:35 AM      ABHINAY GOUD
# 1  ƒ??[21/03/20   2:47:36 PM   Tss Shivasenkar
# 2  ƒ??[21/03/20   3:38:27 PM   Tss Shivasenkar
# 3     [21/03/20   6:27:09 PM      ABHINAY GOUD
# 4     [21/03/20   6:27:25 PM      ABHINAY GOUD
#
#                                              Message
# 0                  Key window Dagara petta\t\t\t\t\t
# 1     ANNAMACHARYA.rar Ÿ??document omitted\t\t\t\t\t
# 2   pick and place robot.rar Ÿ??document omitted\...
# 3         Kshtriya complete chesi pettandi\t\t\t\t\t
# 4           After ugadi vastharu pillaging\t\t\t\t\t

# %%
chat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8134 entries, 0 to 8133
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     7907 non-null   object
#  1   Time     7388 non-null   object
#  2   Name     8134 non-null   object
#  3   Message  7312 non-null   object
# dtypes: object(4)
# memory usage: 254.3+ KB

# %%
chat.isnull().sum()
# Out:
# Date       227
# Time       746
# Name         0
# Message    822
# dtype: int64

# %%
chat.dropna(inplace=True)

# %%
chat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7312 entries, 0 to 8133
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     7312 non-null   object
#  1   Time     7312 non-null   object
#  2   Name     7312 non-null   object
#  3   Message  7312 non-null   object
# dtypes: object(4)
# memory usage: 285.6+ KB

# %%
chat.Name.value_counts()
# Out:
#  Tss Shivasenkar    2300
#  Shekar Tss         2102
#  ABHINAY GOUD       1797
#  Anil               1106
#  Tss-shekar            6
#  +91 98493 99933       1
# Name: Name, dtype: int64

# %%
#chat[(chat.Name==' ABHINAY GOUD')]

# %%
chat.head()
# Out:
#            Date         Time              Name  \
# 0     [21/03/20   7:35:35 AM      ABHINAY GOUD
# 1  ƒ??[21/03/20   2:47:36 PM   Tss Shivasenkar
# 2  ƒ??[21/03/20   3:38:27 PM   Tss Shivasenkar
# 3     [21/03/20   6:27:09 PM      ABHINAY GOUD
# 4     [21/03/20   6:27:25 PM      ABHINAY GOUD
#
#                                              Message
# 0                  Key window Dagara petta\t\t\t\t\t
# 1     ANNAMACHARYA.rar Ÿ??document omitted\t\t\t\t\t
# 2   pick and place robot.rar Ÿ??document omitted\...
# 3         Kshtriya complete chesi pettandi\t\t\t\t\t
# 4           After ugadi vastharu pillaging\t\t\t\t\t

# %%
dummies=pd.get_dummies(chat,columns=['Name'])
dummies
# Out:
#               Date          Time  \
# 0        [21/03/20    7:35:35 AM
# 1     ƒ??[21/03/20    2:47:36 PM
# 2     ƒ??[21/03/20    3:38:27 PM
# 3        [21/03/20    6:27:09 PM
# 4        [21/03/20    6:27:25 PM
# ...            ...           ...
# 8129  ƒ??[19/09/21   11:12:48 AM
# 8130  ƒ??[19/09/21    4:10:47 PM
# 8131  ƒ??[19/09/21    4:19:32 PM
# 8132     [20/09/21    9:05:22 PM
# 8133     [21/09/21    9:37:38 PM
#
#                                                 Message  \
# 0                     Key window Dagara petta\t\t\t\t\t
# 1        ANNAMACHARYA.rar Ÿ??document omitted\t\t\t\t\t
# 2      pick and place robot.rar Ÿ??document omitted\...
# 3            Kshtriya complete chesi pettandi\t\t\t\t\t
# 4              After ugadi vastharu pillaging\t\t\t\t\t
# ...                                                 ...
# 8129   abhi to me\t sankar to mexlsx Ÿ??document omi...
# 8130                         Ÿ??image omitted\t\t\t\t\t
# ...

# %%
dummies.drop(['Name_ +91 98493 99933','Name_ Tss-shekar'],axis=1,inplace=True)

# %%
dummies.head()
# Out:
#            Date         Time  \
# 0     [21/03/20   7:35:35 AM
# 1  ƒ??[21/03/20   2:47:36 PM
# 2  ƒ??[21/03/20   3:38:27 PM
# 3     [21/03/20   6:27:09 PM
# 4     [21/03/20   6:27:25 PM
#
#                                              Message  Name_ ABHINAY GOUD  \
# 0                  Key window Dagara petta\t\t\t\t\t                   1
# 1     ANNAMACHARYA.rar Ÿ??document omitted\t\t\t\t\t                   0
# 2   pick and place robot.rar Ÿ??document omitted\...                   0
# 3         Kshtriya complete chesi pettandi\t\t\t\t\t                   1
# 4           After ugadi vastharu pillaging\t\t\t\t\t                   1
#
#    Name_ Anil  Name_ Shekar Tss  Name_ Tss Shivasenkar
# 0           0                 0                      0
# 1           0                 0                      1
# 2           0                 0                      1
# 3           0                 0                      0
# 4           0                 0                      0

# %%
final_data=pd.DataFrame.rename(dummies,columns={'Name_ ABHINAY GOUD':'abhinay','Name_ Anil':'anil','Name_ Shekar Tss':'shekar','Name_ Tss Shivasenkar':'sankar'})

# %%
final_data.head()
# Out:
#            Date         Time  \
# 0     [21/03/20   7:35:35 AM
# 1  ƒ??[21/03/20   2:47:36 PM
# 2  ƒ??[21/03/20   3:38:27 PM
# 3     [21/03/20   6:27:09 PM
# 4     [21/03/20   6:27:25 PM
#
#                                              Message  abhinay  anil  shekar  \
# 0                  Key window Dagara petta\t\t\t\t\t        1     0       0
# 1     ANNAMACHARYA.rar Ÿ??document omitted\t\t\t\t\t        0     0       0
# 2   pick and place robot.rar Ÿ??document omitted\...        0     0       0
# 3         Kshtriya complete chesi pettandi\t\t\t\t\t        1     0       0
# 4           After ugadi vastharu pillaging\t\t\t\t\t        1     0       0
#
#    sankar
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0

# %%
message_abhinay=final_data[(final_data.abhinay==1)]

# %%
message_abhinay
# Out:
#            Date         Time  \
# 0     [21/03/20   7:35:35 AM
# 3     [21/03/20   6:27:09 PM
# 4     [21/03/20   6:27:25 PM
# 5     [21/03/20   6:41:36 PM
# 12    [22/03/20   9:12:17 AM
# ...         ...          ...
# 8105  [26/08/21   8:59:46 PM
# 8106  [26/08/21   9:00:13 PM
# 8121  [07/09/21   8:54:17 PM
# 8122  [07/09/21   8:54:25 PM
# 8123  [07/09/21   8:54:43 PM
#
#                                                 Message  abhinay  anil  \
# 0                     Key window Dagara petta\t\t\t\t\t        1     0
# 3            Kshtriya complete chesi pettandi\t\t\t\t\t        1     0
# 4              After ugadi vastharu pillaging\t\t\t\t\t        1     0
# 5                Kshtriya valaku doc evvaleda\t\t\t\t\t        1     0
# 12                         Hod nums pampinchu\t\t\t\t\t        1     0
# ...                                                 ...      ...   ...
# 8105   Ma pinni chanipoyindi inti daggra vnna\t\t\t\t\t        1     0
# ...
